# %% [markdown]
# #  Centro

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/alquiler/madrid-comunidad/madrid-provincia/madrid/centro/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_centro"])
df.to_csv("precios_alquiler_centro_sevilla.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/alquiler/madrid-comunidad/madrid-provincia/madrid/centro/historico/
# 📅 2025-07-01 → 💶 25.7335 €/m²
# 📅 2025-06-01 → 💶 25.9895 €/m²
# 📅 2025-05-01 → 💶 25.9461 €/m²
# 📅 2025-04-01 → 💶 25.8133 €/m²
# 📅 2025-03-01 → 💶 25.6793 €/m²
# 📅 2025-02-01 → 💶 25.9842 €/m²
# 📅 2025-01-01 → 💶 25.7113 €/m²
# 📅 2024-12-01 → 💶 25.4751 €/m²
# 📅 2024-11-01 → 💶 24.9786 €/m²
# 📅 2024-10-01 → 💶 24.4437 €/m²
# 📅 2024-09-01 → 💶 24.0 €/m²
# 📅 2024-08-01 → 💶 23.6114 €/m²
# 📅 2024-07-01 → 💶 23.3371 €/m²
# 📅 2024-06-01 → 💶 23.5329 €/m²
# 📅 2024-05-01 → 💶 23.5753 €/m²
# 📅 2024-04-01 → 💶 23.569 €/m²
# 📅 2024-03-01 → 💶 23.3333 €/m²
# 📅 2024-02-01 → 💶 23.0769 €/m²
# 📅 2024-01-01 → 💶 22.5926 €/m²
# 📅 2023-12-01 → 💶 22.093 €/m²
# 📅 2023-11-01 → 💶 21.8182 €/m²
# 📅 2023-10-01 → 💶 21.1667 €/m²
# 📅 2023-09-01 → 💶 20.5855 €/m²
# 📅 2023-08-01 → 💶 20.2953 €/m²
# 📅 2023-07-01 → 💶 19.9904 €/m²
# ...

# %% [markdown]
# # Chamartin

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/chamartin/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_chamartin"])
df.to_csv("precios_alquiler_chamartin_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/chamartin/historico/
# ✅ Datos guardados

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/alquiler/madrid-comunidad/madrid-provincia/madrid/chamberi/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_chamberi"])
df.to_csv("precios_alquiler_chamberi_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/alquiler/madrid-comunidad/madrid-provincia/madrid/chamberi/historico/
# ✅ Datos guardados

# %% [markdown]
# # Moncloa

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/chamberi/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_moncloa"])
df.to_csv("precios_compra_moncloa_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/chamberi/historico/
# 📅 2025-07-01 → 💶 8360.66 €/m²
# 📅 2025-06-01 → 💶 8333.33 €/m²
# 📅 2025-05-01 → 💶 8098.59 €/m²
# 📅 2025-04-01 → 💶 7870.6 €/m²
# 📅 2025-03-01 → 💶 7676.57 €/m²
# 📅 2025-02-01 → 💶 7558.54 €/m²
# 📅 2025-01-01 → 💶 7393.58 €/m²
# 📅 2024-12-01 → 💶 7304.81 €/m²
# 📅 2024-11-01 → 💶 7173.37 €/m²
# 📅 2024-10-01 → 💶 7106.33 €/m²
# 📅 2024-09-01 → 💶 6977.36 €/m²
# 📅 2024-08-01 → 💶 6927.5 €/m²
# 📅 2024-07-01 → 💶 6847.66 €/m²
# 📅 2024-06-01 → 💶 6665.07 €/m²
# 📅 2024-05-01 → 💶 6630.07 €/m²
# 📅 2024-04-01 → 💶 6427.36 €/m²
# 📅 2024-03-01 → 💶 6347.16 €/m²
# 📅 2024-02-01 → 💶 6271.35 €/m²
# 📅 2024-01-01 → 💶 6160.58 €/m²
# 📅 2023-12-01 → 💶 6123.56 €/m²
# 📅 2023-11-01 → 💶 6115.59 €/m²
# 📅 2023-10-01 → 💶 6072.74 €/m²
# 📅 2023-09-01 → 💶 6052.11 €/m²
# 📅 2023-08-01 → 💶 6044.46 €/m²
# 📅 2023-07-01 → 💶 5986.03 €/m²
# ...

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/retiro/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_retiro"])
df.to_csv("precios_compra_retiro_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/retiro/historico/
# 📅 2025-07-01 → 💶 7486.3 €/m²
# 📅 2025-06-01 → 💶 7295.44 €/m²
# 📅 2025-05-01 → 💶 7285.59 €/m²
# 📅 2025-04-01 → 💶 7208.18 €/m²
# 📅 2025-03-01 → 💶 7014.05 €/m²
# 📅 2025-02-01 → 💶 6861.19 €/m²
# 📅 2025-01-01 → 💶 6708.33 €/m²
# 📅 2024-12-01 → 💶 6548.5 €/m²
# 📅 2024-11-01 → 💶 6332.51 €/m²
# 📅 2024-10-01 → 💶 6085.4 €/m²
# 📅 2024-09-01 → 💶 6019.33 €/m²
# 📅 2024-08-01 → 💶 5900.08 €/m²
# 📅 2024-07-01 → 💶 5780.07 €/m²
# 📅 2024-06-01 → 💶 5549.42 €/m²
# 📅 2024-05-01 → 💶 5410.28 €/m²
# 📅 2024-04-01 → 💶 5463.1 €/m²
# 📅 2024-03-01 → 💶 5446.84 €/m²
# 📅 2024-02-01 → 💶 5329.42 €/m²
# 📅 2024-01-01 → 💶 5206.23 €/m²
# 📅 2023-12-01 → 💶 5173.91 €/m²
# 📅 2023-11-01 → 💶 5094.73 €/m²
# 📅 2023-10-01 → 💶 5113.14 €/m²
# 📅 2023-09-01 → 💶 5117.85 €/m²
# 📅 2023-08-01 → 💶 5064.79 €/m²
# 📅 2023-07-01 → 💶 5002.05 €/m²
# ...

# %% [markdown]
# # Salamanca

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/salamanca/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_salamanca"])
df.to_csv("precios_compra_salamanca_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/salamanca/historico/
# 📅 2025-07-01 → 💶 9925.58 €/m²
# 📅 2025-06-01 → 💶 9817.9 €/m²
# 📅 2025-05-01 → 💶 9687.16 €/m²
# 📅 2025-04-01 → 💶 9589.47 €/m²
# 📅 2025-03-01 → 💶 9373.63 €/m²
# 📅 2025-02-01 → 💶 9067.1 €/m²
# 📅 2025-01-01 → 💶 8993.13 €/m²
# 📅 2024-12-01 → 💶 8818.07 €/m²
# 📅 2024-11-01 → 💶 8642.38 €/m²
# 📅 2024-10-01 → 💶 8457.92 €/m²
# 📅 2024-09-01 → 💶 8291.93 €/m²
# 📅 2024-08-01 → 💶 8056.68 €/m²
# 📅 2024-07-01 → 💶 7990.23 €/m²
# 📅 2024-06-01 → 💶 7846.39 €/m²
# 📅 2024-05-01 → 💶 7670.68 €/m²
# 📅 2024-04-01 → 💶 7617.5 €/m²
# 📅 2024-03-01 → 💶 7373.56 €/m²
# 📅 2024-02-01 → 💶 7252.6 €/m²
# 📅 2024-01-01 → 💶 7185.88 €/m²
# 📅 2023-12-01 → 💶 7044.44 €/m²
# 📅 2023-11-01 → 💶 6924.41 €/m²
# 📅 2023-10-01 → 💶 6824.02 €/m²
# 📅 2023-09-01 → 💶 6737.5 €/m²
# 📅 2023-08-01 → 💶 6728.8 €/m²
# 📅 2023-07-01 → 💶 6653.85 €/m²
# ...

# %% [markdown]
# # Majadahonda

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/majadahonda/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_majadahonda"])
df.to_csv("precios_compra_majadahonda_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/majadahonda/historico/
# 📅 2025-07-01 → 💶 4146.85 €/m²
# 📅 2025-06-01 → 💶 4049.25 €/m²
# 📅 2025-05-01 → 💶 3942.54 €/m²
# 📅 2025-04-01 → 💶 3892.55 €/m²
# 📅 2025-03-01 → 💶 3902.65 €/m²
# 📅 2025-02-01 → 💶 3827.93 €/m²
# 📅 2025-01-01 → 💶 3820.36 €/m²
# 📅 2024-12-01 → 💶 3808.43 €/m²
# 📅 2024-11-01 → 💶 3721.08 €/m²
# 📅 2024-10-01 → 💶 3691.56 €/m²
# 📅 2024-09-01 → 💶 3676.24 €/m²
# 📅 2024-08-01 → 💶 3691.88 €/m²
# 📅 2024-07-01 → 💶 3710.61 €/m²
# 📅 2024-06-01 → 💶 3650.24 €/m²
# 📅 2024-05-01 → 💶 3647.08 €/m²
# 📅 2024-04-01 → 💶 3605.05 €/m²
# 📅 2024-03-01 → 💶 3565.22 €/m²
# 📅 2024-02-01 → 💶 3559.09 €/m²
# 📅 2024-01-01 → 💶 3612.49 €/m²
# 📅 2023-12-01 → 💶 3564.29 €/m²
# 📅 2023-11-01 → 💶 3580.95 €/m²
# 📅 2023-10-01 → 💶 3602.74 €/m²
# 📅 2023-09-01 → 💶 3617.12 €/m²
# 📅 2023-08-01 → 💶 3616.32 €/m²
# 📅 2023-07-01 → 💶 3647.32 €/m²
# ...

# %% [markdown]
# # las Rozas

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/las-rozas-de-madrid/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_rozas"])
df.to_csv("precios_compra_rozas_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/las-rozas-de-madrid/historico/
# 📅 2025-07-01 → 💶 3544.08 €/m²
# 📅 2025-06-01 → 💶 3488.25 €/m²
# 📅 2025-05-01 → 💶 3445.16 €/m²
# 📅 2025-04-01 → 💶 3387.79 €/m²
# 📅 2025-03-01 → 💶 3380.49 €/m²
# 📅 2025-02-01 → 💶 3344.86 €/m²
# 📅 2025-01-01 → 💶 3329.06 €/m²
# 📅 2024-12-01 → 💶 3380.71 €/m²
# 📅 2024-11-01 → 💶 3390.45 €/m²
# 📅 2024-10-01 → 💶 3403.58 €/m²
# 📅 2024-09-01 → 💶 3411.32 €/m²
# 📅 2024-08-01 → 💶 3317.73 €/m²
# 📅 2024-07-01 → 💶 3259.34 €/m²
# 📅 2024-06-01 → 💶 3194.97 €/m²
# 📅 2024-05-01 → 💶 3216.21 €/m²
# 📅 2024-04-01 → 💶 3213.57 €/m²
# 📅 2024-03-01 → 💶 3198.74 €/m²
# 📅 2024-02-01 → 💶 3193.1 €/m²
# 📅 2024-01-01 → 💶 3234.9 €/m²
# 📅 2023-12-01 → 💶 3221.15 €/m²
# 📅 2023-11-01 → 💶 3216.44 €/m²
# 📅 2023-10-01 → 💶 3263.25 €/m²
# 📅 2023-09-01 → 💶 3248.08 €/m²
# 📅 2023-08-01 → 💶 3180.19 €/m²
# 📅 2023-07-01 → 💶 3152.25 €/m²
# ...

# %% [markdown]
# # Pozuelo de Alarcon

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/pozuelo-de-alarcon/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_pozuelo"])
df.to_csv("precios_compra_pozuelo_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/pozuelo-de-alarcon/historico/
# 📅 2025-07-01 → 💶 4548.6 €/m²
# 📅 2025-06-01 → 💶 4538.05 €/m²
# 📅 2025-05-01 → 💶 4355.96 €/m²
# 📅 2025-04-01 → 💶 4335.26 €/m²
# 📅 2025-03-01 → 💶 4280.71 €/m²
# 📅 2025-02-01 → 💶 4162.93 €/m²
# 📅 2025-01-01 → 💶 4122.46 €/m²
# 📅 2024-12-01 → 💶 4175.32 €/m²
# 📅 2024-11-01 → 💶 4125.88 €/m²
# 📅 2024-10-01 → 💶 4057.21 €/m²
# 📅 2024-09-01 → 💶 3935.28 €/m²
# 📅 2024-08-01 → 💶 3939.95 €/m²
# 📅 2024-07-01 → 💶 3927.47 €/m²
# 📅 2024-06-01 → 💶 3833.38 €/m²
# 📅 2024-05-01 → 💶 3842.24 €/m²
# 📅 2024-04-01 → 💶 3854.14 €/m²
# 📅 2024-03-01 → 💶 3782.22 €/m²
# 📅 2024-02-01 → 💶 3772.07 €/m²
# 📅 2024-01-01 → 💶 3784.05 €/m²
# 📅 2023-12-01 → 💶 3799.83 €/m²
# 📅 2023-11-01 → 💶 3779.48 €/m²
# 📅 2023-10-01 → 💶 3701.64 €/m²
# 📅 2023-09-01 → 💶 3645.9 €/m²
# 📅 2023-08-01 → 💶 3630.15 €/m²
# 📅 2023-07-01 → 💶 3564.02 €/m²
# ...

# %% [markdown]
# # Torrodolones

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/torrelodones/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_torrodolones"])
df.to_csv("precios_compra_torrodolones_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/torrelodones/historico/
# 📅 2025-07-01 → 💶 2669.02 €/m²
# 📅 2025-06-01 → 💶 2633.27 €/m²
# 📅 2025-05-01 → 💶 2627.77 €/m²
# 📅 2025-04-01 → 💶 2621.46 €/m²
# 📅 2025-03-01 → 💶 2622.97 €/m²
# 📅 2025-02-01 → 💶 2661.22 €/m²
# 📅 2025-01-01 → 💶 2602.85 €/m²
# 📅 2024-12-01 → 💶 2768.22 €/m²
# 📅 2024-11-01 → 💶 2729.14 €/m²
# 📅 2024-10-01 → 💶 2707.71 €/m²
# 📅 2024-09-01 → 💶 2701.16 €/m²
# 📅 2024-08-01 → 💶 2648.67 €/m²
# 📅 2024-07-01 → 💶 2578.03 €/m²
# 📅 2024-06-01 → 💶 2649.3 €/m²
# 📅 2024-05-01 → 💶 2640.23 €/m²
# 📅 2024-04-01 → 💶 2639.01 €/m²
# 📅 2024-03-01 → 💶 2540.38 €/m²
# 📅 2024-02-01 → 💶 2484.14 €/m²
# 📅 2024-01-01 → 💶 2469.1 €/m²
# 📅 2023-12-01 → 💶 2448.36 €/m²
# 📅 2023-11-01 → 💶 2519.27 €/m²
# 📅 2023-10-01 → 💶 2511.3 €/m²
# 📅 2023-09-01 → 💶 2446.81 €/m²
# 📅 2023-08-01 → 💶 2408.4 €/m²
# 📅 2023-07-01 → 💶 2421.91 €/m²
# ...

# %% [markdown]
# # Villanuvea de la cañada

# %%
import undetected_chromedriver as uc
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
import random
import subprocess
import re

# Detectar versión principal de Chrome
def obtener_version_chrome():
    try:
        salida = subprocess.check_output(r'reg query "HKEY_CURRENT_USER\Software\Google\Chrome\BLBeacon" /v version', shell=True)
        version = re.search(r"(\d+)\.", salida.decode()).group(1)
        return int(version)
    except Exception as e:
        print("❌ No se pudo detectar la versión de Chrome:", e)
        return None

version_main = obtener_version_chrome()
print("Versión de Chrome detectada:", version_main)

# Configurar navegador
options = uc.ChromeOptions()
options.add_argument("--start-maximized")
# options.add_argument("--headless")

# Iniciar navegador con versión detectada
browser = uc.Chrome(options=options, version_main=version_main)

# Acceder a la URL de Idealista
url = "https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/villanueva-de-la-canada/historico/"
print(f"🌐 Accediendo a: {url}")
browser.get(url)
time.sleep(random.uniform(5, 7))

# Parsear contenido
soup = bs(browser.page_source, 'lxml')
filas = soup.select('table.component-table tbody tr')

datos = []
for fila in filas:
    celdas = fila.find_all('td')
    if len(celdas) >= 2:
        fecha = celdas[0].get('data-sortable')
        precio_str = celdas[1].get('data-sortable')
        if fecha and precio_str:
            try:
                precio = float(precio_str)
                datos.append((fecha, precio))
                print(f"📅 {fecha} → 💶 {precio} €/m²")
            except:
                continue

# Guardar en CSV
df = pd.DataFrame(datos, columns=["Fecha", "Precio_m2_villanueva"])
df.to_csv("precios_compra_villanueva_madrid.csv", index=False, encoding='utf-8')
print("✅ Datos guardados")

browser.quit()
# Out:
# Versión de Chrome detectada: 138
# 🌐 Accediendo a: https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/villanueva-de-la-canada/historico/
# 📅 2025-07-01 → 💶 2730.83 €/m²
# 📅 2025-06-01 → 💶 2713.6 €/m²
# 📅 2025-05-01 → 💶 2774.2 €/m²
# 📅 2025-04-01 → 💶 2710.48 €/m²
# 📅 2025-03-01 → 💶 2546.65 €/m²
# 📅 2025-02-01 → 💶 2562.31 €/m²
# 📅 2025-01-01 → 💶 2609.26 €/m²
# 📅 2024-12-01 → 💶 2656.21 €/m²
# 📅 2024-11-01 → 💶 2727.01 €/m²
# 📅 2024-10-01 → 💶 2624.46 €/m²
# 📅 2024-09-01 → 💶 2521.9 €/m²
# 📅 2024-08-01 → 💶 2395.82 €/m²
# 📅 2024-07-01 → 💶 2411.46 €/m²
# 📅 2024-06-01 → 💶 2469.06 €/m²
# 📅 2024-05-01 → 💶 2461.78 €/m²
# 📅 2024-04-01 → 💶 2436.52 €/m²
# 📅 2024-03-01 → 💶 2427.36 €/m²
# 📅 2024-02-01 → 💶 2446.19 €/m²
# 📅 2024-01-01 → 💶 2382.23 €/m²
# 📅 2023-12-01 → 💶 2255.62 €/m²
# 📅 2023-11-01 → 💶 2229.6 €/m²
# 📅 2023-10-01 → 💶 2237.24 €/m²
# 📅 2023-09-01 → 💶 2254.69 €/m²
# 📅 2023-08-01 → 💶 2314.49 €/m²
# 📅 2023-07-01 → 💶 2332.93 €/m²
# ...
