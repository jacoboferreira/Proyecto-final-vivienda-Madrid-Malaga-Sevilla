# %%
import requests
from bs4 import BeautifulSoup as bs
import random
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import undetected_chromedriver as uc
import time
import math
import glob
import os

# %% [markdown]
# # Centro

# %%
# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_centro.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_centro.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_centro.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108649983
#
# 📄 Parseando inmueble: 100086672
#
# 📄 Parseando inmueble: 105407203
#
# 📄 Parseando inmueble: 99564765
#
# 📄 Parseando inmueble: 108651419
#
# 📄 Parseando inmueble: 92863859
#
# 📄 Parseando inmueble: 108640831
#
# 📄 Parseando inmueble: 102207245
#
# 📄 Parseando inmueble: 108649900
#
# 📄 Parseando inmueble: 108265632
#
# 📄 Parseando inmueble: 108642951
#
# 📄 Parseando inmueble: 108295523
#
# 📄 Parseando inmueble: 108651238
#
# 📄 Parseando inmueble: 102304050
#
# 📄 Parseando inmueble: 108651201
#
# 📄 Parseando inmueble: 108319123
#
# 📄 Parseando inmueble: 106628956
#
# 📄 Parseando inmueble: 101781534
#
# 📄 Parseando inmueble: 108650801
#
# 📄 Parseando inmueble: 106399240
#
# 📄 Parseando inmueble: 108650799
#
# 📄 Parseando inmueble: 108436999
#
# 📄 Parseando inmueble: 89610605
#
# 📄 Parseando inmueble: 101113524
#
# 📄 Parseando inmueble: 108650705
#
# 📄 Parseando inmueble: 99274614
#
# 📄 Parseando inmueble: 108650669
#
# ...

# %% [markdown]
# # Pozuelo

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_Pozuelo.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_pozuelo.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_pozuelo.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108584099
#
# 📄 Parseando inmueble: 108584165
#
# 📄 Parseando inmueble: 108652564
#
# 📄 Parseando inmueble: 95045852
#
# 📄 Parseando inmueble: 108652527
#
# 📄 Parseando inmueble: 107892846
#
# 📄 Parseando inmueble: 108652445
#
# 📄 Parseando inmueble: 105464576
#
# 📄 Parseando inmueble: 108651943
#
# 📄 Parseando inmueble: 107531060
#
# 📄 Parseando inmueble: 105471823
#
# 📄 Parseando inmueble: 28820540
#
# 📄 Parseando inmueble: 108643994
#
# 📄 Parseando inmueble: 103089700
#
# 📄 Parseando inmueble: 108643986
#
# 📄 Parseando inmueble: 94761970
#
# 📄 Parseando inmueble: 108643946
#
# 📄 Parseando inmueble: 97092204
#
# 📄 Parseando inmueble: 108638752
#
# 📄 Parseando inmueble: 108210129
#
# 📄 Parseando inmueble: 90012088
#
# 📄 Parseando inmueble: 107763322
#
# 📄 Parseando inmueble: 99560103
#
# 📄 Parseando inmueble: 106332556
#
# 📄 Parseando inmueble: 108636141
#
# 📄 Parseando inmueble: 107763042
#
# 📄 Parseando inmueble: 101564892
#
# 📄 Parseando inmueble: 107798066
# ...

# %% [markdown]
# # Chamartin

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_chamartin.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_chamartin.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_chamartin.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108638522
#
# 📄 Parseando inmueble: 108499886
#
# 📄 Parseando inmueble: 105231342
#
# 📄 Parseando inmueble: 103076644
#
# 📄 Parseando inmueble: 105362816
#
# 📄 Parseando inmueble: 90103071
#
# 📄 Parseando inmueble: 40314760
#
# 📄 Parseando inmueble: 102168281
#
# 📄 Parseando inmueble: 108637638
#
# 📄 Parseando inmueble: 34453401
#
# 📄 Parseando inmueble: 108637171
#
# 📄 Parseando inmueble: 36796910
#
# 📄 Parseando inmueble: 107694369
#
# 📄 Parseando inmueble: 108636990
#
# 📄 Parseando inmueble: 105712943
#
# 📄 Parseando inmueble: 99703353
#
# 📄 Parseando inmueble: 107592178
#
# 📄 Parseando inmueble: 108636473
#
# 📄 Parseando inmueble: 108571750
#
# 📄 Parseando inmueble: 108622818
#
# 📄 Parseando inmueble: 108629490
#
# 📄 Parseando inmueble: 108634406
#
# 📄 Parseando inmueble: 108533798
#
# 📄 Parseando inmueble: 108636246
#
# 📄 Parseando inmueble: 108547316
#
# 📄 Parseando inmueble: 108635986
#
# 📄 Parseando inmueble: 108160223
#
# ...

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_chamberi.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_chamberi.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_chamberi.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 93970072
#
# 📄 Parseando inmueble: 108562536
#
# 📄 Parseando inmueble: 97341082
#
# 📄 Parseando inmueble: 108610902
#
# 📄 Parseando inmueble: 108634772
#
# 📄 Parseando inmueble: 108262382
#
# 📄 Parseando inmueble: 88590480
#
# 📄 Parseando inmueble: 108290570
#
# 📄 Parseando inmueble: 108633713
#
# 📄 Parseando inmueble: 106260111
#
# 📄 Parseando inmueble: 108633616
#
# 📄 Parseando inmueble: 108393045
#
# 📄 Parseando inmueble: 91167646
#
# 📄 Parseando inmueble: 105754231
#
# 📄 Parseando inmueble: 101950504
#
# 📄 Parseando inmueble: 108448195
#
# 📄 Parseando inmueble: 108632567
#
# 📄 Parseando inmueble: 108577208
#
# 📄 Parseando inmueble: 37109299
#
# 📄 Parseando inmueble: 105572889
#
# 📄 Parseando inmueble: 95377001
#
# 📄 Parseando inmueble: 108447700
#
# 📄 Parseando inmueble: 108632442
#
# 📄 Parseando inmueble: 108442427
#
# 📄 Parseando inmueble: 108632470
#
# 📄 Parseando inmueble: 95091336
#
# 📄 Parseando inmueble: 108625179
#
# 📄 Parseando inmueble: 108603678
# ...

# %% [markdown]
# # Majadahonda

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_Majadahonda.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_Majadahonda.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_Majadahonda.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 104491482
#
# 📄 Parseando inmueble: 107877174
#
# 📄 Parseando inmueble: 96212862
#
# 📄 Parseando inmueble: 105166773
#
# 📄 Parseando inmueble: 108642911
#
# 📄 Parseando inmueble: 108641336
#
# 📄 Parseando inmueble: 25387880
#
# 📄 Parseando inmueble: 108639613
#
# 📄 Parseando inmueble: 108637724
#
# 📄 Parseando inmueble: 95357955
#
# 📄 Parseando inmueble: 28219223
#
# 📄 Parseando inmueble: 108620759
#
# 📄 Parseando inmueble: 89317792
#
# 📄 Parseando inmueble: 106425085
#
# 📄 Parseando inmueble: 108566754
#
# 📄 Parseando inmueble: 107353764
#
# 📄 Parseando inmueble: 106143343
#
# 📄 Parseando inmueble: 107401131
#
# 📄 Parseando inmueble: 108536328
#
# 📄 Parseando inmueble: 106927642
#
# 📄 Parseando inmueble: 108352632
#
# 📄 Parseando inmueble: 90887349
#
# 📄 Parseando inmueble: 87609156
#
# 📄 Parseando inmueble: 105473641
#
# 📄 Parseando inmueble: 106166225
#
# 📄 Parseando inmueble: 108469197
#
# 📄 Parseando inmueble: 108618846
#
# 📄 Parseando inmueble: 108630946
# ...

# %% [markdown]
# # Moncloa

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_moncloa.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_moncloa.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_moncloa.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108634869
#
# 📄 Parseando inmueble: 108548246
#
# 📄 Parseando inmueble: 30143507
#
# 📄 Parseando inmueble: 26499665
#
# 📄 Parseando inmueble: 108635411
#
# 📄 Parseando inmueble: 108537806
#
# 📄 Parseando inmueble: 87180521
#
# 📄 Parseando inmueble: 104205069
#
# 📄 Parseando inmueble: 108634163
#
# 📄 Parseando inmueble: 102496755
#
# 📄 Parseando inmueble: 105387415
#
# 📄 Parseando inmueble: 104963226
#
# 📄 Parseando inmueble: 31576647
#
# 📄 Parseando inmueble: 89510553
#
# 📄 Parseando inmueble: 101649190
#
# 📄 Parseando inmueble: 108280776
#
# 📄 Parseando inmueble: 94326790
#
# 📄 Parseando inmueble: 89903959
#
# 📄 Parseando inmueble: 108631237
#
# 📄 Parseando inmueble: 108571555
#
# 📄 Parseando inmueble: 108630531
#
# 📄 Parseando inmueble: 108238848
#
# 📄 Parseando inmueble: 108558127
#
# 📄 Parseando inmueble: 108520909
#
# 📄 Parseando inmueble: 108629386
#
# 📄 Parseando inmueble: 106865738
#
# 📄 Parseando inmueble: 108628799
#
# 📄 Parseando inmueble: 108228405
# ...

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_retiro.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_retiro.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_retiro.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108649431
#
# 📄 Parseando inmueble: 104275295
#
# 📄 Parseando inmueble: 81553179
#
# 📄 Parseando inmueble: 108584754
#
# 📄 Parseando inmueble: 98273261
#
# 📄 Parseando inmueble: 108238587
#
# 📄 Parseando inmueble: 85379732
#
# 📄 Parseando inmueble: 108622387
#
# 📄 Parseando inmueble: 108647077
#
# 📄 Parseando inmueble: 94452150
#
# 📄 Parseando inmueble: 108646715
#
# 📄 Parseando inmueble: 103350532
#
# 📄 Parseando inmueble: 99013793
#
# 📄 Parseando inmueble: 103727022
#
# 📄 Parseando inmueble: 108646216
#
# 📄 Parseando inmueble: 90477593
#
# 📄 Parseando inmueble: 108645514
#
# 📄 Parseando inmueble: 102608882
#
# 📄 Parseando inmueble: 108644889
#
# 📄 Parseando inmueble: 100366215
#
# 📄 Parseando inmueble: 107077529
#
# 📄 Parseando inmueble: 108530448
#
# 📄 Parseando inmueble: 108644114
#
# 📄 Parseando inmueble: 108358540
#
# 📄 Parseando inmueble: 108643632
#
# 📄 Parseando inmueble: 105497662
#
# 📄 Parseando inmueble: 108642835
#
# 📄 Parseando inmueble: 107281846
# ...

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_zona_norte.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_zona_norte.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_zona_norte.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108707889
#
# 📄 Parseando inmueble: 108284687
#
# 📄 Parseando inmueble: 108706698
#
# 📄 Parseando inmueble: 108705324
#
# 📄 Parseando inmueble: 108706582
#
# 📄 Parseando inmueble: 103515411
#
# 📄 Parseando inmueble: 108705810
#
# 📄 Parseando inmueble: 108698337
#
# 📄 Parseando inmueble: 108705771
#
# 📄 Parseando inmueble: 108691559
#
# 📄 Parseando inmueble: 108705335
#
# 📄 Parseando inmueble: 108693889
#
# 📄 Parseando inmueble: 108705109
#
# 📄 Parseando inmueble: 108650985
#
# 📄 Parseando inmueble: 89412418
#
# 📄 Parseando inmueble: 107431761
#
# 📄 Parseando inmueble: 108704303
#
# 📄 Parseando inmueble: 88000885
#
# 📄 Parseando inmueble: 108704473
#
# 📄 Parseando inmueble: 105991872
#
# 📄 Parseando inmueble: 108704225
#
# 📄 Parseando inmueble: 93655532
#
# 📄 Parseando inmueble: 108704186
#
# 📄 Parseando inmueble: 108630797
#
# 📄 Parseando inmueble: 108696072
#
# 📄 Parseando inmueble: 107812778
#
# 📄 Parseando inmueble: 108703741
#
# ...

# %% [markdown]
# # Salamanca

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_salamanca.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_salamanca.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_salamanca.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108641731
#
# 📄 Parseando inmueble: 105046411
#
# 📄 Parseando inmueble: 108641714
#
# 📄 Parseando inmueble: 108395716
#
# 📄 Parseando inmueble: 98447070
#
# 📄 Parseando inmueble: 25255628
#
# 📄 Parseando inmueble: 92079111
#
# 📄 Parseando inmueble: 102283536
#
# 📄 Parseando inmueble: 108641068
#
# 📄 Parseando inmueble: 28918473
#
# 📄 Parseando inmueble: 105294494
#
# 📄 Parseando inmueble: 97552317
#
# 📄 Parseando inmueble: 105595803
#
# 📄 Parseando inmueble: 105639239
#
# 📄 Parseando inmueble: 108640565
#
# 📄 Parseando inmueble: 108239571
#
# 📄 Parseando inmueble: 108640275
#
# 📄 Parseando inmueble: 108574103
#
# 📄 Parseando inmueble: 108639926
#
# 📄 Parseando inmueble: 39746562
#
# 📄 Parseando inmueble: 108639885
#
# 📄 Parseando inmueble: 96783121
#
# 📄 Parseando inmueble: 105969359
#
# 📄 Parseando inmueble: 107112547
#
# 📄 Parseando inmueble: 102166644
#
# 📄 Parseando inmueble: 108562172
#
# 📄 Parseando inmueble: 108638641
#
# 📄 Parseando inmueble: 108578004
# ...

# %% [markdown]
# # Tetuan

# %%
import undetected_chromedriver as uc
import time
import random
import pandas as pd
from bs4 import BeautifulSoup as bs

# Cargar tu DataFrame con IDs
datos_compra2 = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Jacobo\\DATOS PISOS\\PROYECTO FINAL\\ALQUILER\\casa_alquiler_Tetuan.csv", sep=';', encoding='utf-16')  # Asegúrate del encoding correcto
ids_casas_C = datos_compra2[['id']].dropna().drop_duplicates().astype(str)

# Iniciar navegador
options = uc.ChromeOptions()
# options.add_argument("--headless")  # Descomenta si no quieres ver el navegador
browser = uc.Chrome(options=options)

# ------------------------------------------
# FUNCIÓN PARA PARSEAR CADA INMUEBLE
# ------------------------------------------
def parsear_inmueble(id_muebles):
    print(f"\n📄 Parseando inmueble: {id_muebles}")
    url = f'https://www.idealista.com/inmueble/{id_muebles}/'
    browser.get(url)
    time.sleep(2)
    soup = bs(browser.page_source, 'lxml')

    try:
        edificio = []
        edificio_header = soup.find('h2', string='Edificio')
        if edificio_header:
            edificio_div = edificio_header.find_next_sibling('div', class_='details-property_features')
            if edificio_div:
                edificio = [li.text.strip() for li in edificio_div.find_all('li')]
                
        return {
            'id': id_muebles,
            'edificio': edificio,
        }

    except Exception as e:
        print(f"❌ Error al parsear {id_muebles}: {e}")
        return None

# ------------------------------------------
# PARSEAR TODOS LOS INMUEBLES
# ------------------------------------------
resultados = []

for id_mueble in ids_casas_C['id']:
    resultado = parsear_inmueble(id_mueble)
    if resultado:
        resultados.append(resultado)
    time.sleep(random.randint(1, 2))

# Convertir a DataFrame
df_casas_C = pd.DataFrame(resultados)

# Guardar a CSV final
df_casas_C.to_csv('casa_alquiler_edificio_Tetuan.csv', index=False, sep=';', encoding='utf-16')

# Cerrar el navegador
browser.quit()

print("✅ Proceso completo. Datos guardados en casa_alquiler_edificio_Tetuan.csv")
print(df_casas_C.shape)
# Out:
# 📄 Parseando inmueble: 108699429
#
# 📄 Parseando inmueble: 105094027
#
# 📄 Parseando inmueble: 108704608
#
# 📄 Parseando inmueble: 108654650
#
# 📄 Parseando inmueble: 108704433
#
# 📄 Parseando inmueble: 108654504
#
# 📄 Parseando inmueble: 93931626
#
# 📄 Parseando inmueble: 108653252
#
# 📄 Parseando inmueble: 108704344
#
# 📄 Parseando inmueble: 100867893
#
# 📄 Parseando inmueble: 108704373
#
# 📄 Parseando inmueble: 102806096
#
# 📄 Parseando inmueble: 102345923
#
# 📄 Parseando inmueble: 106528848
#
# 📄 Parseando inmueble: 108702992
#
# 📄 Parseando inmueble: 106553543
#
# 📄 Parseando inmueble: 108702379
#
# 📄 Parseando inmueble: 106991522
#
# 📄 Parseando inmueble: 108703855
#
# 📄 Parseando inmueble: 108581884
#
# 📄 Parseando inmueble: 108702028
#
# 📄 Parseando inmueble: 107565531
#
# 📄 Parseando inmueble: 108701690
#
# 📄 Parseando inmueble: 101128622
#
# 📄 Parseando inmueble: 108701801
#
# 📄 Parseando inmueble: 108679606
#
# 📄 Parseando inmueble: 108703397
#
# ...

# %% [markdown]
# # Unir información

# %%
import glob
import os
import pandas as pd
import numpy as np

# %%
# Ruta de la carpeta donde están los CSVs
carpeta = r'C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR'

# Buscar todos los archivos .csv en esa carpeta
csv_files = glob.glob(os.path.join(carpeta, '*.csv'))

# Lista para guardar los DataFrames
dataframes = []

# Leer y agregar cada archivo a la lista
for file in csv_files:
    print(f'📂 Leyendo: {file}')
    df = pd.read_csv(file, encoding='utf-16', sep=';', engine='python', on_bad_lines='skip')
    dataframes.append(df)

# Concatenar todos los DataFrames en uno solo
df_total = pd.concat(dataframes, ignore_index=True)

# Guardar el CSV combinado
salida = os.path.join(carpeta, 'datos_unificados_añadir_alquiler.csv')
df_total.to_csv(salida, index=False, sep=';', encoding='utf-16')

print(f'✅ CSV unificado guardado en: {salida}')
# Out:
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_centro.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_chamartin.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_chamberi.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_Majadahonda.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_moncloa.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_pozuelo.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_retiro.csv
# 📂 Leyendo: C:\Users\LENOVO\Desktop\Jacobo\DATOS PISOS\PROYECTO FINAL\ALQUILER\AÑADIR\casa_alquiler_edificio_rozas.csv
# ...

# %%
ruta = 'datos_unificados_añadir_alquiler.csv'
df = pd.read_csv(ruta,  sep=';', encoding='utf-16')

# %%
df.head(20)
# Out:
#            id                                edificio
# 0   108649983                                      []
# 1   100086672                                      []
# 2   105407203                                      []
# 3    99564765  ['Planta 3ª exterior', 'Con ascensor']
# 4   108651419  ['Planta 1ª exterior', 'Sin ascensor']
# 5    92863859       ['Bajo exterior', 'Sin ascensor']
# 6   108640831  ['Planta 3ª interior', 'Con ascensor']
# 7   102207245                                      []
# 8   108649900                                      []
# 9   108265632                                      []
# 10  108642951       ['Bajo interior', 'Sin ascensor']
# 11  108295523                                      []
# 12  108651238                                      []
# 13  102304050  ['Planta 1ª exterior', 'Sin ascensor']
# 14  108651201                                      []
# 15  108319123                                      []
# ...

# %%
df.shape
# Out:
# (13952, 2)

# %%
df['edificio'].isnull().sum()
# Out:
# 0
